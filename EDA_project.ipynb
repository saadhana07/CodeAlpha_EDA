# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset("tips")

# %%
print("First 5 rows:")
print(df.head())
# Out:
# First 5 rows:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
print("\nDataset Info:")
print(df.info())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# None

# %%
print("\nSummary Statistics:")
print(df.describe())
# Out:
# Summary Statistics:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
sns.barplot(x='day', y='total_bill', data=df)
plt.title("Total Bill by Day")
plt.show()

# %%
sns.scatterplot(x='total_bill', y='tip', hue='time', data=df)
plt.title("Total Bill vs Tip")
plt.show()

# %%
sns.regplot(x='total_bill', y='tip', data=df)
plt.title("Relationship Between Total Bill and Tip")
plt.show()

# %%
sns.boxplot(x=df['total_bill'])
plt.title("Outliers in Total Bill")
plt.show()

# %%
sns.boxplot(x='time', y='total_bill', data=df)
plt.title("Lunch vs Dinner Spending")
plt.show()

# %%
print("\nINSIGHTS:")
print("1. Higher total bill leads to higher tips.")
print("2. Dinner time shows higher spending than lunch.")
print("3. Some outliers exist in total bill.")
print("4. Spending varies across different days.")
# Out:
# INSIGHTS:
# 1. Higher total bill leads to higher tips.
# 2. Dinner time shows higher spending than lunch.
# 3. Some outliers exist in total bill.
# 4. Spending varies across different days.
